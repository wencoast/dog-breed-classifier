# %%
import sys
import os
import tarfile
import shutil
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from utils import *
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle
from scipy import ndimage, io, misc
from xml.dom import minidom

# %%
# %matplotlib inline

# %%
# %mkdir train
# %mkdir test
# %mkdir cropped
# %mkdir cropped/train
# %mkdir cropped/test
# Out:
# mkdir: cannot create directory ‘train’: File exists
# mkdir: cannot create directory ‘test’: File exists
# mkdir: cannot create directory ‘cropped’: File exists

# %%
url = 'http://vision.stanford.edu/aditya86/ImageNetDogs/'
last_percent_reported = None
data_root = '.'
num_classes = 120
image_size = 224
num_channels = 3
np.random.seed(133)

# %%
def download_progress_hook(count, blockSize, totalSize):
    """
    A hook to report the progress of a download. This is mostly intended for users with
    slow internet connections. Reports every 5% change in download progress.
    """
    global last_percent_reported
    percent = int(count * blockSize * 100 / totalSize)

    if last_percent_reported != percent:
        if percent % 5 == 0:
            sys.stdout.write("%s%%" % percent)
            sys.stdout.flush()
        else:
            sys.stdout.write(".")
            sys.stdout.flush()

    last_percent_reported = percent

# %%
def maybe_download(filename, expected_bytes, force=False):
    """
    Download a file if not present, and make sure it's the right size.
    """
    dest_filename = os.path.join(data_root, filename)
    if force or not os.path.exists(dest_filename):
        print('Attempting to download:', filename) 
        filename, _ = urlretrieve(url + filename, dest_filename, reporthook=download_progress_hook)
        print('\nDownload Complete!')
    statinfo = os.stat(dest_filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', dest_filename)
    else:
        raise Exception('Failed to verify ' + dest_filename + '. Can you get to it with a browser?')
    return dest_filename

# %%
def maybe_extract(filename, check_classes=True, force=False):
    root = os.path.splitext(filename)[0]  # remove .tar
    if os.path.isdir(root) and not force:
        print('%s already present - Skipping extraction of %s.' % (root, filename))
    else:
        print('Extracting data for %s. This may take a while. Please wait.' % root)
        tar = tarfile.open(filename)
        sys.stdout.flush()
        tar.extractall(data_root)
        tar.close()
    if check_classes:
        data_folders = [os.path.join(root, d) for d in sorted(os.listdir(root)) if os.path.isdir(os.path.join(root, d))]
        if len(data_folders) != num_classes:
            raise Exception('Expected %d folders, one per class. Found %d instead.' % (num_classes, len(data_folders)))
        print('Completed extraction of %s.' % filename)
        return data_folders
    else:
        print('Completed extraction of %s.' % filename)

# %%
images_filename = maybe_download('images.tar', 793579520)
annotation_filename = maybe_download('annotation.tar', 21852160)
lists_filename = maybe_download('lists.tar', 481280)
# Out:
# ('Found and verified', './images.tar')
# ('Found and verified', './annotation.tar')
# ('Found and verified', './lists.tar')

# %%
images_filename = './images'
annotation_filename = './annotation'

# %%
images_folders = maybe_extract(images_filename)
annotation_folders = maybe_extract(annotation_filename)
maybe_extract(lists_filename, check_classes=False)
# Out:
# ./Images already present - Skipping extraction of ./Images.
# Completed extraction of ./Images.
# ./Annotation already present - Skipping extraction of ./Annotation.
# Completed extraction of ./Annotation.
# Extracting data for ./lists. This may take a while. Please wait.
# Completed extraction of ./lists.tar.

# %%
for folder in images_folders:
    os.makedirs("train/"+folder.split("/")[-1])
    os.makedirs("test/"+folder.split("/")[-1])
    os.makedirs("cropped/train/"+folder.split("/")[-1])
    os.makedirs("cropped/test/"+folder.split("/")[-1])

# %%
test_list = io.loadmat('test_list.mat')['file_list']
train_list = io.loadmat('train_list.mat')['file_list']

# %%
def move_data_files(image_list, new_folder):
    for file in image_list:
        if os.path.exists('./Images/'+file[0][0]):
            shutil.move('./Images/'+file[0][0], './'+new_folder+'/'+file[0][0])
        elif not os.path.exists('./'+new_folder+'/'+file[0][0]):
           print('%s does not exist, it may be missing' % os.path.exists('./images/'+file[0][0]))
    return [os.path.join(new_folder, d) for d in sorted(os.listdir(new_folder)) if os.path.isdir(os.path.join(new_folder, d))]

# %%
test_folders = move_data_files(test_list, 'test')
train_folders = move_data_files(train_list, 'train')

# %%
def load_breed(folder):
    """
    Load the data for a single breed label.
    """
    image_files = os.listdir(folder)
    dataset = np.ndarray(shape=(len(image_files), num_channels, image_size, image_size), dtype=np.float32)
    print(folder)
    num_images = 0
    for image in image_files:
        image_file = os.path.join(folder, image)
        try:
            image_data = misc.imread(image_file)[:,:,:3]
            
            annon_file = annotation_filename + '/' + folder.split('/')[-1] + '/' + image.split('.')[0]
            annon_xml = minidom.parse(annon_file)
            xmin = int(annon_xml.getElementsByTagName('xmin')[0].firstChild.nodeValue)
            ymin = int(annon_xml.getElementsByTagName('ymin')[0].firstChild.nodeValue)
            xmax = int(annon_xml.getElementsByTagName('xmax')[0].firstChild.nodeValue)
            ymax = int(annon_xml.getElementsByTagName('ymax')[0].firstChild.nodeValue)
            
            new_image_data = image_data[ymin:ymax,xmin:xmax,:]
            new_image_data = misc.imresize(new_image_data, (image_size, image_size))
            misc.imsave('cropped/' + folder + '/' + image, new_image_data)
            dataset[num_images, :, :, :] = new_image_data.swapaxes(1,2).swapaxes(0,1)[1]
            num_images = num_images + 1
        except IOError as e:
            print('Could not read:', image_file, ':', e, '- it\'s ok, skipping.')

    dataset = dataset[0:num_images, :, :, :]

    print('Full dataset tensor:', dataset.shape)
    return dataset

# %%
def maybe_pickle(data_folders, force=False):
    dataset_names = []
    for folder in data_folders:
        set_filename = folder + '.pickle'
        dataset_names.append(set_filename)
        if os.path.exists(set_filename) and not force:
            print('%s already present - Skipping pickling.' % set_filename)
        else:
            print('Pickling %s.' % set_filename)
            dataset = load_breed(folder)
            try:
                with open(set_filename, 'wb') as f:
                    pickle.dump(dataset, f, pickle.HIGHEST_PROTOCOL)
            except Exception as e:
                print('Unable to save data to', set_filename, ':', e)
  
    return dataset_names

# %%
train_datasets = maybe_pickle(train_folders, force=True)
test_datasets = maybe_pickle(test_folders, force=True)
# Out:
# Pickling train/n02085620-Chihuahua.pickle.
# train/n02085620-Chihuahua
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02085782-Japanese_spaniel.pickle.
# train/n02085782-Japanese_spaniel
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02085936-Maltese_dog.pickle.
# train/n02085936-Maltese_dog
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02086079-Pekinese.pickle.
# train/n02086079-Pekinese
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02086240-Shih-Tzu.pickle.
# train/n02086240-Shih-Tzu
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02086646-Blenheim_spaniel.pickle.
# train/n02086646-Blenheim_spaniel
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02086910-papillon.pickle.
# train/n02086910-papillon
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02087046-toy_terrier.pickle.
# train/n02087046-toy_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02087394-Rhodesian_ridgeback.pickle.
# train/n02087394-Rhodesian_ridgeback
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02088094-Afghan_hound.pickle.
# train/n02088094-Afghan_hound
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02088238-basset.pickle.
# train/n02088238-basset
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02088364-beagle.pickle.
# train/n02088364-beagle
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02088466-bloodhound.pickle.
# train/n02088466-bloodhound
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02088632-bluetick.pickle.
# train/n02088632-bluetick
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02089078-black-and-tan_coonhound.pickle.
# train/n02089078-black-and-tan_coonhound
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02089867-Walker_hound.pickle.
# train/n02089867-Walker_hound
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02089973-English_foxhound.pickle.
# train/n02089973-English_foxhound
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02090379-redbone.pickle.
# train/n02090379-redbone
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02090622-borzoi.pickle.
# train/n02090622-borzoi
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02090721-Irish_wolfhound.pickle.
# train/n02090721-Irish_wolfhound
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02091032-Italian_greyhound.pickle.
# train/n02091032-Italian_greyhound
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02091134-whippet.pickle.
# train/n02091134-whippet
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02091244-Ibizan_hound.pickle.
# train/n02091244-Ibizan_hound
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02091467-Norwegian_elkhound.pickle.
# train/n02091467-Norwegian_elkhound
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02091635-otterhound.pickle.
# train/n02091635-otterhound
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02091831-Saluki.pickle.
# train/n02091831-Saluki
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02092002-Scottish_deerhound.pickle.
# train/n02092002-Scottish_deerhound
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02092339-Weimaraner.pickle.
# train/n02092339-Weimaraner
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02093256-Staffordshire_bullterrier.pickle.
# train/n02093256-Staffordshire_bullterrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02093428-American_Staffordshire_terrier.pickle.
# train/n02093428-American_Staffordshire_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02093647-Bedlington_terrier.pickle.
# train/n02093647-Bedlington_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02093754-Border_terrier.pickle.
# train/n02093754-Border_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02093859-Kerry_blue_terrier.pickle.
# train/n02093859-Kerry_blue_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02093991-Irish_terrier.pickle.
# train/n02093991-Irish_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02094114-Norfolk_terrier.pickle.
# train/n02094114-Norfolk_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02094258-Norwich_terrier.pickle.
# train/n02094258-Norwich_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02094433-Yorkshire_terrier.pickle.
# train/n02094433-Yorkshire_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02095314-wire-haired_fox_terrier.pickle.
# train/n02095314-wire-haired_fox_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02095570-Lakeland_terrier.pickle.
# train/n02095570-Lakeland_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02095889-Sealyham_terrier.pickle.
# train/n02095889-Sealyham_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02096051-Airedale.pickle.
# train/n02096051-Airedale
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02096177-cairn.pickle.
# train/n02096177-cairn
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02096294-Australian_terrier.pickle.
# train/n02096294-Australian_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02096437-Dandie_Dinmont.pickle.
# train/n02096437-Dandie_Dinmont
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02096585-Boston_bull.pickle.
# train/n02096585-Boston_bull
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02097047-miniature_schnauzer.pickle.
# train/n02097047-miniature_schnauzer
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02097130-giant_schnauzer.pickle.
# train/n02097130-giant_schnauzer
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02097209-standard_schnauzer.pickle.
# train/n02097209-standard_schnauzer
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02097298-Scotch_terrier.pickle.
# train/n02097298-Scotch_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02097474-Tibetan_terrier.pickle.
# train/n02097474-Tibetan_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02097658-silky_terrier.pickle.
# train/n02097658-silky_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02098105-soft-coated_wheaten_terrier.pickle.
# train/n02098105-soft-coated_wheaten_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02098286-West_Highland_white_terrier.pickle.
# train/n02098286-West_Highland_white_terrier
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02098413-Lhasa.pickle.
# train/n02098413-Lhasa
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02099267-flat-coated_retriever.pickle.
# train/n02099267-flat-coated_retriever
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02099429-curly-coated_retriever.pickle.
# train/n02099429-curly-coated_retriever
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02099601-golden_retriever.pickle.
# train/n02099601-golden_retriever
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02099712-Labrador_retriever.pickle.
# train/n02099712-Labrador_retriever
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02099849-Chesapeake_Bay_retriever.pickle.
# train/n02099849-Chesapeake_Bay_retriever
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02100236-German_short-haired_pointer.pickle.
# train/n02100236-German_short-haired_pointer
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02100583-vizsla.pickle.
# train/n02100583-vizsla
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02100735-English_setter.pickle.
# train/n02100735-English_setter
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02100877-Irish_setter.pickle.
# train/n02100877-Irish_setter
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02101006-Gordon_setter.pickle.
# train/n02101006-Gordon_setter
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02101388-Brittany_spaniel.pickle.
# train/n02101388-Brittany_spaniel
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02101556-clumber.pickle.
# train/n02101556-clumber
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02102040-English_springer.pickle.
# train/n02102040-English_springer
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02102177-Welsh_springer_spaniel.pickle.
# train/n02102177-Welsh_springer_spaniel
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02102318-cocker_spaniel.pickle.
# train/n02102318-cocker_spaniel
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02102480-Sussex_spaniel.pickle.
# train/n02102480-Sussex_spaniel
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02102973-Irish_water_spaniel.pickle.
# train/n02102973-Irish_water_spaniel
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02104029-kuvasz.pickle.
# train/n02104029-kuvasz
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02104365-schipperke.pickle.
# train/n02104365-schipperke
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02105056-groenendael.pickle.
# train/n02105056-groenendael
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02105162-malinois.pickle.
# train/n02105162-malinois
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02105251-briard.pickle.
# train/n02105251-briard
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02105412-kelpie.pickle.
# train/n02105412-kelpie
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02105505-komondor.pickle.
# train/n02105505-komondor
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02105641-Old_English_sheepdog.pickle.
# train/n02105641-Old_English_sheepdog
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02105855-Shetland_sheepdog.pickle.
# train/n02105855-Shetland_sheepdog
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02106030-collie.pickle.
# train/n02106030-collie
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02106166-Border_collie.pickle.
# train/n02106166-Border_collie
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02106382-Bouvier_des_Flandres.pickle.
# train/n02106382-Bouvier_des_Flandres
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02106550-Rottweiler.pickle.
# train/n02106550-Rottweiler
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02106662-German_shepherd.pickle.
# train/n02106662-German_shepherd
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02107142-Doberman.pickle.
# train/n02107142-Doberman
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02107312-miniature_pinscher.pickle.
# train/n02107312-miniature_pinscher
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02107574-Greater_Swiss_Mountain_dog.pickle.
# train/n02107574-Greater_Swiss_Mountain_dog
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02107683-Bernese_mountain_dog.pickle.
# train/n02107683-Bernese_mountain_dog
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02107908-Appenzeller.pickle.
# train/n02107908-Appenzeller
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02108000-EntleBucher.pickle.
# train/n02108000-EntleBucher
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02108089-boxer.pickle.
# train/n02108089-boxer
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02108422-bull_mastiff.pickle.
# train/n02108422-bull_mastiff
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02108551-Tibetan_mastiff.pickle.
# train/n02108551-Tibetan_mastiff
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02108915-French_bulldog.pickle.
# train/n02108915-French_bulldog
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02109047-Great_Dane.pickle.
# train/n02109047-Great_Dane
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02109525-Saint_Bernard.pickle.
# train/n02109525-Saint_Bernard
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02109961-Eskimo_dog.pickle.
# train/n02109961-Eskimo_dog
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02110063-malamute.pickle.
# train/n02110063-malamute
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02110185-Siberian_husky.pickle.
# train/n02110185-Siberian_husky
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02110627-affenpinscher.pickle.
# train/n02110627-affenpinscher
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02110806-basenji.pickle.
# train/n02110806-basenji
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02110958-pug.pickle.
# train/n02110958-pug
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02111129-Leonberg.pickle.
# train/n02111129-Leonberg
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02111277-Newfoundland.pickle.
# train/n02111277-Newfoundland
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02111500-Great_Pyrenees.pickle.
# train/n02111500-Great_Pyrenees
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02111889-Samoyed.pickle.
# train/n02111889-Samoyed
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02112018-Pomeranian.pickle.
# train/n02112018-Pomeranian
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02112137-chow.pickle.
# train/n02112137-chow
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02112350-keeshond.pickle.
# train/n02112350-keeshond
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02112706-Brabancon_griffon.pickle.
# train/n02112706-Brabancon_griffon
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02113023-Pembroke.pickle.
# train/n02113023-Pembroke
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02113186-Cardigan.pickle.
# train/n02113186-Cardigan
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02113624-toy_poodle.pickle.
# train/n02113624-toy_poodle
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02113712-miniature_poodle.pickle.
# train/n02113712-miniature_poodle
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02113799-standard_poodle.pickle.
# train/n02113799-standard_poodle
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02113978-Mexican_hairless.pickle.
# train/n02113978-Mexican_hairless
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02115641-dingo.pickle.
# train/n02115641-dingo
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02115913-dhole.pickle.
# train/n02115913-dhole
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling train/n02116738-African_hunting_dog.pickle.
# train/n02116738-African_hunting_dog
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling test/n02085620-Chihuahua.pickle.
# test/n02085620-Chihuahua
# ('Full dataset tensor:', (52, 3, 224, 224))
# Pickling test/n02085782-Japanese_spaniel.pickle.
# test/n02085782-Japanese_spaniel
# ('Full dataset tensor:', (85, 3, 224, 224))
# Pickling test/n02085936-Maltese_dog.pickle.
# test/n02085936-Maltese_dog
# ('Full dataset tensor:', (152, 3, 224, 224))
# Pickling test/n02086079-Pekinese.pickle.
# test/n02086079-Pekinese
# ('Full dataset tensor:', (49, 3, 224, 224))
# Pickling test/n02086240-Shih-Tzu.pickle.
# test/n02086240-Shih-Tzu
# ('Full dataset tensor:', (114, 3, 224, 224))
# Pickling test/n02086646-Blenheim_spaniel.pickle.
# test/n02086646-Blenheim_spaniel
# ('Full dataset tensor:', (88, 3, 224, 224))
# Pickling test/n02086910-papillon.pickle.
# test/n02086910-papillon
# ('Full dataset tensor:', (96, 3, 224, 224))
# Pickling test/n02087046-toy_terrier.pickle.
# test/n02087046-toy_terrier
# ('Full dataset tensor:', (72, 3, 224, 224))
# Pickling test/n02087394-Rhodesian_ridgeback.pickle.
# test/n02087394-Rhodesian_ridgeback
# ('Full dataset tensor:', (72, 3, 224, 224))
# Pickling test/n02088094-Afghan_hound.pickle.
# test/n02088094-Afghan_hound
# ('Full dataset tensor:', (139, 3, 224, 224))
# Pickling test/n02088238-basset.pickle.
# test/n02088238-basset
# ('Full dataset tensor:', (75, 3, 224, 224))
# Pickling test/n02088364-beagle.pickle.
# test/n02088364-beagle
# ('Full dataset tensor:', (95, 3, 224, 224))
# Pickling test/n02088466-bloodhound.pickle.
# test/n02088466-bloodhound
# ('Full dataset tensor:', (87, 3, 224, 224))
# Pickling test/n02088632-bluetick.pickle.
# test/n02088632-bluetick
# ('Full dataset tensor:', (71, 3, 224, 224))
# Pickling test/n02089078-black-and-tan_coonhound.pickle.
# test/n02089078-black-and-tan_coonhound
# ('Full dataset tensor:', (59, 3, 224, 224))
# Pickling test/n02089867-Walker_hound.pickle.
# test/n02089867-Walker_hound
# ('Full dataset tensor:', (53, 3, 224, 224))
# Pickling test/n02089973-English_foxhound.pickle.
# test/n02089973-English_foxhound
# ('Full dataset tensor:', (57, 3, 224, 224))
# Pickling test/n02090379-redbone.pickle.
# test/n02090379-redbone
# ('Full dataset tensor:', (48, 3, 224, 224))
# Pickling test/n02090622-borzoi.pickle.
# test/n02090622-borzoi
# ('Full dataset tensor:', (51, 3, 224, 224))
# Pickling test/n02090721-Irish_wolfhound.pickle.
# test/n02090721-Irish_wolfhound
# ('Full dataset tensor:', (118, 3, 224, 224))
# Pickling test/n02091032-Italian_greyhound.pickle.
# test/n02091032-Italian_greyhound
# ('Full dataset tensor:', (82, 3, 224, 224))
# Pickling test/n02091134-whippet.pickle.
# test/n02091134-whippet
# ('Full dataset tensor:', (87, 3, 224, 224))
# Pickling test/n02091244-Ibizan_hound.pickle.
# test/n02091244-Ibizan_hound
# ('Full dataset tensor:', (88, 3, 224, 224))
# Pickling test/n02091467-Norwegian_elkhound.pickle.
# test/n02091467-Norwegian_elkhound
# ('Full dataset tensor:', (96, 3, 224, 224))
# Pickling test/n02091635-otterhound.pickle.
# test/n02091635-otterhound
# ('Full dataset tensor:', (51, 3, 224, 224))
# Pickling test/n02091831-Saluki.pickle.
# test/n02091831-Saluki
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling test/n02092002-Scottish_deerhound.pickle.
# test/n02092002-Scottish_deerhound
# ('Full dataset tensor:', (132, 3, 224, 224))
# Pickling test/n02092339-Weimaraner.pickle.
# test/n02092339-Weimaraner
# ('Full dataset tensor:', (60, 3, 224, 224))
# Pickling test/n02093256-Staffordshire_bullterrier.pickle.
# test/n02093256-Staffordshire_bullterrier
# ('Full dataset tensor:', (55, 3, 224, 224))
# Pickling test/n02093428-American_Staffordshire_terrier.pickle.
# test/n02093428-American_Staffordshire_terrier
# ('Full dataset tensor:', (64, 3, 224, 224))
# Pickling test/n02093647-Bedlington_terrier.pickle.
# test/n02093647-Bedlington_terrier
# ('Full dataset tensor:', (82, 3, 224, 224))
# Pickling test/n02093754-Border_terrier.pickle.
# test/n02093754-Border_terrier
# ('Full dataset tensor:', (72, 3, 224, 224))
# Pickling test/n02093859-Kerry_blue_terrier.pickle.
# test/n02093859-Kerry_blue_terrier
# ('Full dataset tensor:', (79, 3, 224, 224))
# Pickling test/n02093991-Irish_terrier.pickle.
# test/n02093991-Irish_terrier
# ('Full dataset tensor:', (69, 3, 224, 224))
# Pickling test/n02094114-Norfolk_terrier.pickle.
# test/n02094114-Norfolk_terrier
# ('Full dataset tensor:', (72, 3, 224, 224))
# Pickling test/n02094258-Norwich_terrier.pickle.
# test/n02094258-Norwich_terrier
# ('Full dataset tensor:', (85, 3, 224, 224))
# Pickling test/n02094433-Yorkshire_terrier.pickle.
# test/n02094433-Yorkshire_terrier
# ('Full dataset tensor:', (64, 3, 224, 224))
# Pickling test/n02095314-wire-haired_fox_terrier.pickle.
# test/n02095314-wire-haired_fox_terrier
# ('Full dataset tensor:', (57, 3, 224, 224))
# Pickling test/n02095570-Lakeland_terrier.pickle.
# test/n02095570-Lakeland_terrier
# ('Full dataset tensor:', (97, 3, 224, 224))
# Pickling test/n02095889-Sealyham_terrier.pickle.
# test/n02095889-Sealyham_terrier
# ('Full dataset tensor:', (102, 3, 224, 224))
# Pickling test/n02096051-Airedale.pickle.
# test/n02096051-Airedale
# ('Full dataset tensor:', (102, 3, 224, 224))
# Pickling test/n02096177-cairn.pickle.
# test/n02096177-cairn
# ('Full dataset tensor:', (97, 3, 224, 224))
# Pickling test/n02096294-Australian_terrier.pickle.
# test/n02096294-Australian_terrier
# ('Full dataset tensor:', (96, 3, 224, 224))
# Pickling test/n02096437-Dandie_Dinmont.pickle.
# test/n02096437-Dandie_Dinmont
# ('Full dataset tensor:', (80, 3, 224, 224))
# Pickling test/n02096585-Boston_bull.pickle.
# test/n02096585-Boston_bull
# ('Full dataset tensor:', (82, 3, 224, 224))
# Pickling test/n02097047-miniature_schnauzer.pickle.
# test/n02097047-miniature_schnauzer
# ('Full dataset tensor:', (54, 3, 224, 224))
# Pickling test/n02097130-giant_schnauzer.pickle.
# test/n02097130-giant_schnauzer
# ('Full dataset tensor:', (57, 3, 224, 224))
# Pickling test/n02097209-standard_schnauzer.pickle.
# test/n02097209-standard_schnauzer
# ('Full dataset tensor:', (55, 3, 224, 224))
# Pickling test/n02097298-Scotch_terrier.pickle.
# test/n02097298-Scotch_terrier
# ('Full dataset tensor:', (58, 3, 224, 224))
# Pickling test/n02097474-Tibetan_terrier.pickle.
# test/n02097474-Tibetan_terrier
# ('Full dataset tensor:', (106, 3, 224, 224))
# Pickling test/n02097658-silky_terrier.pickle.
# test/n02097658-silky_terrier
# ('Full dataset tensor:', (83, 3, 224, 224))
# Pickling test/n02098105-soft-coated_wheaten_terrier.pickle.
# test/n02098105-soft-coated_wheaten_terrier
# ('Full dataset tensor:', (56, 3, 224, 224))
# Pickling test/n02098286-West_Highland_white_terrier.pickle.
# test/n02098286-West_Highland_white_terrier
# ('Full dataset tensor:', (69, 3, 224, 224))
# Pickling test/n02098413-Lhasa.pickle.
# test/n02098413-Lhasa
# ('Full dataset tensor:', (86, 3, 224, 224))
# Pickling test/n02099267-flat-coated_retriever.pickle.
# test/n02099267-flat-coated_retriever
# ('Full dataset tensor:', (52, 3, 224, 224))
# Pickling test/n02099429-curly-coated_retriever.pickle.
# test/n02099429-curly-coated_retriever
# ('Full dataset tensor:', (51, 3, 224, 224))
# Pickling test/n02099601-golden_retriever.pickle.
# test/n02099601-golden_retriever
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02099712-Labrador_retriever.pickle.
# test/n02099712-Labrador_retriever
# ('Full dataset tensor:', (71, 3, 224, 224))
# Pickling test/n02099849-Chesapeake_Bay_retriever.pickle.
# test/n02099849-Chesapeake_Bay_retriever
# ('Full dataset tensor:', (67, 3, 224, 224))
# Pickling test/n02100236-German_short-haired_pointer.pickle.
# test/n02100236-German_short-haired_pointer
# ('Full dataset tensor:', (52, 3, 224, 224))
# Pickling test/n02100583-vizsla.pickle.
# test/n02100583-vizsla
# ('Full dataset tensor:', (54, 3, 224, 224))
# Pickling test/n02100735-English_setter.pickle.
# test/n02100735-English_setter
# ('Full dataset tensor:', (61, 3, 224, 224))
# Pickling test/n02100877-Irish_setter.pickle.
# test/n02100877-Irish_setter
# ('Full dataset tensor:', (55, 3, 224, 224))
# Pickling test/n02101006-Gordon_setter.pickle.
# test/n02101006-Gordon_setter
# ('Full dataset tensor:', (53, 3, 224, 224))
# Pickling test/n02101388-Brittany_spaniel.pickle.
# test/n02101388-Brittany_spaniel
# ('Full dataset tensor:', (52, 3, 224, 224))
# Pickling test/n02101556-clumber.pickle.
# test/n02101556-clumber
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02102040-English_springer.pickle.
# test/n02102040-English_springer
# ('Full dataset tensor:', (59, 3, 224, 224))
# Pickling test/n02102177-Welsh_springer_spaniel.pickle.
# test/n02102177-Welsh_springer_spaniel
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02102318-cocker_spaniel.pickle.
# test/n02102318-cocker_spaniel
# ('Full dataset tensor:', (59, 3, 224, 224))
# Pickling test/n02102480-Sussex_spaniel.pickle.
# test/n02102480-Sussex_spaniel
# ('Full dataset tensor:', (51, 3, 224, 224))
# Pickling test/n02102973-Irish_water_spaniel.pickle.
# test/n02102973-Irish_water_spaniel
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02104029-kuvasz.pickle.
# test/n02104029-kuvasz
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02104365-schipperke.pickle.
# test/n02104365-schipperke
# ('Full dataset tensor:', (54, 3, 224, 224))
# Pickling test/n02105056-groenendael.pickle.
# test/n02105056-groenendael
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02105162-malinois.pickle.
# test/n02105162-malinois
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02105251-briard.pickle.
# test/n02105251-briard
# ('Full dataset tensor:', (52, 3, 224, 224))
# Pickling test/n02105412-kelpie.pickle.
# test/n02105412-kelpie
# ('Full dataset tensor:', (53, 3, 224, 224))
# Pickling test/n02105505-komondor.pickle.
# test/n02105505-komondor
# ('Full dataset tensor:', (54, 3, 224, 224))
# Pickling test/n02105641-Old_English_sheepdog.pickle.
# test/n02105641-Old_English_sheepdog
# ('Full dataset tensor:', (69, 3, 224, 224))
# Pickling test/n02105855-Shetland_sheepdog.pickle.
# test/n02105855-Shetland_sheepdog
# ('Full dataset tensor:', (57, 3, 224, 224))
# Pickling test/n02106030-collie.pickle.
# test/n02106030-collie
# ('Full dataset tensor:', (53, 3, 224, 224))
# Pickling test/n02106166-Border_collie.pickle.
# test/n02106166-Border_collie
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02106382-Bouvier_des_Flandres.pickle.
# test/n02106382-Bouvier_des_Flandres
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02106550-Rottweiler.pickle.
# test/n02106550-Rottweiler
# ('Full dataset tensor:', (52, 3, 224, 224))
# Pickling test/n02106662-German_shepherd.pickle.
# test/n02106662-German_shepherd
# ('Full dataset tensor:', (52, 3, 224, 224))
# Pickling test/n02107142-Doberman.pickle.
# test/n02107142-Doberman
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02107312-miniature_pinscher.pickle.
# test/n02107312-miniature_pinscher
# ('Full dataset tensor:', (84, 3, 224, 224))
# Pickling test/n02107574-Greater_Swiss_Mountain_dog.pickle.
# test/n02107574-Greater_Swiss_Mountain_dog
# ('Full dataset tensor:', (68, 3, 224, 224))
# Pickling test/n02107683-Bernese_mountain_dog.pickle.
# test/n02107683-Bernese_mountain_dog
# ('Full dataset tensor:', (118, 3, 224, 224))
# Pickling test/n02107908-Appenzeller.pickle.
# test/n02107908-Appenzeller
# ('Full dataset tensor:', (51, 3, 224, 224))
# Pickling test/n02108000-EntleBucher.pickle.
# test/n02108000-EntleBucher
# ('Full dataset tensor:', (102, 3, 224, 224))
# Pickling test/n02108089-boxer.pickle.
# test/n02108089-boxer
# ('Full dataset tensor:', (51, 3, 224, 224))
# Pickling test/n02108422-bull_mastiff.pickle.
# test/n02108422-bull_mastiff
# ('Full dataset tensor:', (56, 3, 224, 224))
# Pickling test/n02108551-Tibetan_mastiff.pickle.
# test/n02108551-Tibetan_mastiff
# ('Full dataset tensor:', (52, 3, 224, 224))
# Pickling test/n02108915-French_bulldog.pickle.
# test/n02108915-French_bulldog
# ('Full dataset tensor:', (59, 3, 224, 224))
# Pickling test/n02109047-Great_Dane.pickle.
# test/n02109047-Great_Dane
# ('Full dataset tensor:', (56, 3, 224, 224))
# Pickling test/n02109525-Saint_Bernard.pickle.
# test/n02109525-Saint_Bernard
# ('Full dataset tensor:', (70, 3, 224, 224))
# Pickling test/n02109961-Eskimo_dog.pickle.
# test/n02109961-Eskimo_dog
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02110063-malamute.pickle.
# test/n02110063-malamute
# ('Full dataset tensor:', (78, 3, 224, 224))
# Pickling test/n02110185-Siberian_husky.pickle.
# test/n02110185-Siberian_husky
# ('Full dataset tensor:', (92, 3, 224, 224))
# Pickling test/n02110627-affenpinscher.pickle.
# test/n02110627-affenpinscher
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02110806-basenji.pickle.
# test/n02110806-basenji
# ('Full dataset tensor:', (109, 3, 224, 224))
# Pickling test/n02110958-pug.pickle.
# test/n02110958-pug
# ('Full dataset tensor:', (100, 3, 224, 224))
# Pickling test/n02111129-Leonberg.pickle.
# test/n02111129-Leonberg
# ('Full dataset tensor:', (110, 3, 224, 224))
# Pickling test/n02111277-Newfoundland.pickle.
# test/n02111277-Newfoundland
# ('Full dataset tensor:', (95, 3, 224, 224))
# Pickling test/n02111500-Great_Pyrenees.pickle.
# test/n02111500-Great_Pyrenees
# ('Full dataset tensor:', (113, 3, 224, 224))
# Pickling test/n02111889-Samoyed.pickle.
# test/n02111889-Samoyed
# ('Full dataset tensor:', (118, 3, 224, 224))
# Pickling test/n02112018-Pomeranian.pickle.
# test/n02112018-Pomeranian
# ('Full dataset tensor:', (119, 3, 224, 224))
# Pickling test/n02112137-chow.pickle.
# test/n02112137-chow
# ('Full dataset tensor:', (96, 3, 224, 224))
# Pickling test/n02112350-keeshond.pickle.
# test/n02112350-keeshond
# ('Full dataset tensor:', (58, 3, 224, 224))
# Pickling test/n02112706-Brabancon_griffon.pickle.
# test/n02112706-Brabancon_griffon
# ('Full dataset tensor:', (53, 3, 224, 224))
# Pickling test/n02113023-Pembroke.pickle.
# test/n02113023-Pembroke
# ('Full dataset tensor:', (81, 3, 224, 224))
# Pickling test/n02113186-Cardigan.pickle.
# test/n02113186-Cardigan
# ('Full dataset tensor:', (55, 3, 224, 224))
# Pickling test/n02113624-toy_poodle.pickle.
# test/n02113624-toy_poodle
# ('Full dataset tensor:', (51, 3, 224, 224))
# Pickling test/n02113712-miniature_poodle.pickle.
# test/n02113712-miniature_poodle
# ('Full dataset tensor:', (55, 3, 224, 224))
# Pickling test/n02113799-standard_poodle.pickle.
# test/n02113799-standard_poodle
# ('Full dataset tensor:', (59, 3, 224, 224))
# Pickling test/n02113978-Mexican_hairless.pickle.
# test/n02113978-Mexican_hairless
# ('Full dataset tensor:', (55, 3, 224, 224))
# Pickling test/n02115641-dingo.pickle.
# test/n02115641-dingo
# ('Full dataset tensor:', (56, 3, 224, 224))
# Pickling test/n02115913-dhole.pickle.
# test/n02115913-dhole
# ('Full dataset tensor:', (50, 3, 224, 224))
# Pickling test/n02116738-African_hunting_dog.pickle.
# test/n02116738-African_hunting_dog
# ('Full dataset tensor:', (69, 3, 224, 224))

# %%
def make_arrays(nb_rows, img_size):
    if nb_rows:
        dataset = np.ndarray((nb_rows, num_channels, img_size, img_size), dtype=np.float32)
        labels = np.ndarray(nb_rows, dtype=np.int32)
    else:
        dataset, labels = None, None
    return dataset, labels

# %%
def merge_datasets(pickle_files, train_size, valid_size=0, even_size=True):
    num_classes = len(pickle_files)
    valid_dataset, valid_labels = make_arrays(valid_size, image_size)
    train_dataset, train_labels = make_arrays(train_size, image_size)
    vsize_per_class = valid_size // num_classes
    tsize_per_class = train_size // num_classes
    
    start_v, start_t = 0, 0
    end_v, end_t = vsize_per_class, tsize_per_class
    end_l = vsize_per_class+tsize_per_class
    for label, pickle_file in enumerate(pickle_files):
        try:
            with open(pickle_file, 'rb') as f:
                breed_set = pickle.load(f)
                np.random.shuffle(breed_set)
                
            if not even_size:
                tsize_per_class,end_l = len(breed_set),len(breed_set)
                end_t = start_t + tsize_per_class
                
            if valid_dataset is not None:
                valid_breed = breed_set[:vsize_per_class, :, :, :]
                valid_dataset[start_v:end_v, :, :, :] = valid_breed
                valid_labels[start_v:end_v] = label
                start_v += vsize_per_class
                end_v += vsize_per_class

            
            train_breed = breed_set[vsize_per_class:end_l, :, :, :]
            train_dataset[start_t:end_t, :, :, :] = train_breed
            train_labels[start_t:end_t] = label
            start_t += tsize_per_class
            end_t += tsize_per_class
        except Exception as e:
            print('Unable to process data from', pickle_file, ':', e)
            raise
    
    return valid_dataset, valid_labels, train_dataset, train_labels

# %%
train_size = 9600
valid_size = 2400
test_size = 8580

valid_dataset, valid_labels, train_dataset, train_labels = merge_datasets(
  train_datasets, train_size, valid_size)
_, _, test_dataset, test_labels = merge_datasets(test_datasets, test_size, even_size=False)

print('Training:', train_dataset.shape, train_labels.shape)
print('Validation:', valid_dataset.shape, valid_labels.shape)
print('Testing:', test_dataset.shape, test_labels.shape)
# Out:
# ('Training:', (9600, 3, 224, 224), (9600,))
# ('Validation:', (2400, 3, 224, 224), (2400,))
# ('Testing:', (8580, 3, 224, 224), (8580,))

# %%
save_array('train_dataset.dat', train_dataset)
save_array('train_labels.dat', train_labels)
save_array('valid_dataset.dat', valid_dataset)
save_array('valid_labels.dat', valid_labels)
save_array('test_dataset.dat', test_dataset)
save_array('test_labels.dat', test_labels)
